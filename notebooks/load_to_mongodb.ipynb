# %%
import os

from pymongo import MongoClient
from pymongo.errors import OperationFailure
import pandas as pd

import h5py
import time
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
from pandas import DataFrame
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
def check_mongo_connection(client_uri):
    connection = MongoClient(client_uri)

    try:
        connection.database_names
        print('\n')
        print(f'Data Base Connection to {client_uri} Established........')
        print('DBs available:')
        for db_name in connection.list_databases():
            print(' DB Name:', db_name['name'])
            db = connection[db_name['name']]
            collections =[]
            for collection_name in db.list_collection_names():
                collections.append(collection_name)
            print('   Colections:', collections)
          
        
    except OperationFailure as err:
        print(f"Data Base Connection failed. Error: {err}")

    return connection

client_uri = "mongodb://192.168.1.20:27017"
server = check_mongo_connection(client_uri)
# Out:
# Data Base Connection to mongodb://192.168.1.20:27017 Established........
# DBs available:
#  DB Name: admin
#    Colections: ['system.version']
#  DB Name: config
#    Colections: ['system.sessions']
#  DB Name: local
#    Colections: ['startup_log']

# %% [markdown]
# ## Source Dataset 1
# 6. Turbofan Engine Degradation Simulation
# Engine degradation simulation was carried out using the Commercial Modular Aero-Propulsion System Simulation (C-MAPSS). Four different sets were simulated under different combinations of operational conditions and fault modes. This records several sensor channels to characterize fault evolution. The data set was provided by the NASA Ames Prognostics Center of Excellence (PCoE).
#
# https://data.nasa.gov/Aerospace/CMAPSS-Jet-Engine-Simulated-Data/ff5v-kuh6
# #### Read and Store Raw Data to DB

# %%
# Raw files descriptions from website notes 
meta_data = [
    {
        'Data Set': 'FD001',
        'Train trajectories': 100,
        'Test trajectories': 100,
        'Conditions': 'ONE (Sea Level)',
        'Fault Modes': 'ONE (HPC Degradation)'
    },
    {
        'Data Set': 'FD002',
        'Train trajectories': 260,
        'Test trajectories': 259,
        'Conditions': 'SIX',
        'Fault Modes': 'ONE (HPC Degradation)'
    },
    {
        'Data Set': 'FD003',
        'Train trajectories': 100,
        'Test trajectories': 100,
        'Conditions': 'ONE (Sea Level)',
        'Fault Modes': 'TWO (HPC Degradation, Fan Degradation)'
    },
    {
        'Data Set': 'FD004',
        'Train trajectories': 248,
        'Test trajectories': 249,
        'Conditions': 'SIX',
        'Fault Modes': 'TWO (HPC Degradation, Fan Degradation)'
    },

]

column_names = [
    'unit #', 'time (cycles)', 'op. setting 1', 'op. setting 2', 'op. setting 3',
    'sensor 01', 'sensor 02', 'sensor 03', 'sensor 04', 'sensor 05',
    'sensor 06', 'sensor 07', 'sensor 08', 'sensor 09', 'sensor 10',
    'sensor 11', 'sensor 12', 'sensor 13', 'sensor 14', 'sensor 15',
    'sensor 16', 'sensor 17', 'sensor 18', 'sensor 19', 'sensor 20', 'sensor 21',
]

data_sets = pd.DataFrame.from_records(meta_data)

data_sets.set_index('Data Set', inplace = True)
# data_sets

# %%
# Read downloaded data and create DB tables (MongoDB Collections)
def data_records(data_sets):

    file_path = '/Volumes/share/Datasets/6_TurbofanEngineDegradationSimulationDataSet/CMAPSSData/'
    file_prefixes = ['train', 'test']
    column_groups = {}
    database = server[db_set1]
    for data_set, row in data_sets.iterrows():
        columns = {}
        for prefix in file_prefixes:
            full_path = ''.join([file_path, prefix, '_', data_set,'.txt'])
            df = pd.read_csv(full_path, sep=" ")
            df.dropna(axis=1, how='all', inplace=True)
            df.columns = column_names

            # Store dataset in the DB

            colection = database[''.join([prefix, '_', data_set])]
            print('Create mongodb collection:', colection)
            new_data = colection.insert_many(df.to_dict('records'))
            print(f'Collection {colection} created')
        column_groups[data_set] = columns

    return column_groups


db_set1 = 'TurboFanDegradation_Set1'

file_prefix = ['train', 'test']
record_columns = data_records(data_sets)
new_columns = pd.DataFrame.from_dict(record_columns,orient='index')

data_sets = pd.concat([data_sets, new_columns], axis=1)
data_sets
# Out:
# Create mongodb collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'train_FD001')
# Collection Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'train_FD001') created
# Create mongodb collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'test_FD001')
# Collection Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'test_FD001') created
# Create mongodb collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'train_FD002')
# Collection Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'train_FD002') created
# Create mongodb collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'test_FD002')
# Collection Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'test_FD002') created
# Create mongodb collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'train_FD003')
# Collection Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'train_FD003') created
# Create mongodb collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'test_FD003')
# Collection Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'test_FD003') created
# Create mongodb collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'train_FD004')
# Collection Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'train_FD004') created
# Create mongodb collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'test_FD004')
# Collection Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set1'), 'test_FD004') created
#           Train trajectories  Test trajectories       Conditions  \
# Data Set
# FD001                    100                100  ONE (Sea Level)
# FD002                    260                259              SIX
# FD003                    100                100  ONE (Sea Level)
# FD004                    248                249              SIX
#
#                                      Fault Modes
# Data Set
# FD001                      ONE (HPC Degradation)
# FD002                      ONE (HPC Degradation)
# FD003     TWO (HPC Degradation, Fan Degradation)
# FD004     TWO (HPC Degradation, Fan Degradation)

# %%
# List the new created tables (Mongo DB collections)
# list of strings
collections = server[db_set1].list_collection_names()
collections = sorted(collections)
documents = []
for collection in collections:
    documents.append(server[db_set1][collection].estimated_document_count())
   
# Calling DataFrame constructor after zipping
# both lists, with columns specified
mongo_collections_df = pd.DataFrame(list(zip(collections, documents)),
               columns =['Collection', 'Documents (Tot. Records)'])
mongo_collections_df
# Out:
#     Collection  Documents (Tot. Records)
# 0   test_FD001                     13095
# 1   test_FD002                     33990
# 2   test_FD003                     16595
# 3   test_FD004                     41213
# 4  train_FD001                     20630
# 5  train_FD002                     53758
# 6  train_FD003                     24719
# 7  train_FD004                     61248

# %% [markdown]
# ## Source Dataset 2
# 17. Turbofan Engine Degradation Simulation-2
# The generation of data-driven prognostics models requires the availability of data sets with run-to-failure trajectories. To contribute to the development of these methods, the data set provides a new realistic data set of run-to-failure trajectories for a small fleet of aircraft engines under realistic flight conditions. The damage propagation modelling used for the generation of this synthetic data set builds on the modeling strategy from previous work. The data set was generated with the Commercial Modular Aero-Propulsion System Simulation (C-MAPSS) dynamical model. The data set has been provided by the NASA Prognostics Center of Excellence (PCoE) in collaboration with ETH Zurich and PARC.
#
# https://phm-datasets.s3.amazonaws.com/NASA/17.+Turbofan+Engine+Degradation+Simulation+Data+Set+2.zip
# #### Read and Store Raw Data to DB

# %%
# Data files are very large and scored in H5 format
# The following function opends de files and 
def read_h5_file(filename):
    # Time tracking, Operation time (min):  0.003
    t = time.process_time()  

    # Load data
    with h5py.File(filename, 'r') as hdf:
            # Development set
            W_dev = np.array(hdf.get('W_dev'))             # W
            X_s_dev = np.array(hdf.get('X_s_dev'))         # X_s
            X_v_dev = np.array(hdf.get('X_v_dev'))         # X_v
            T_dev = np.array(hdf.get('T_dev'))             # T
            Y_dev = np.array(hdf.get('Y_dev'))             # RUL  
            A_dev = np.array(hdf.get('A_dev'))             # Auxiliary

            # Test set
            W_test = np.array(hdf.get('W_test'))           # W
            X_s_test = np.array(hdf.get('X_s_test'))       # X_s
            X_v_test = np.array(hdf.get('X_v_test'))       # X_v
            T_test = np.array(hdf.get('T_test'))           # T
            Y_test = np.array(hdf.get('Y_test'))           # RUL  
            A_test = np.array(hdf.get('A_test'))           # Auxiliary
            
            # Varnams
            W_var = np.array(hdf.get('W_var'))
            X_s_var = np.array(hdf.get('X_s_var'))  
            X_v_var = np.array(hdf.get('X_v_var')) 
            T_var = np.array(hdf.get('T_var'))
            A_var = np.array(hdf.get('A_var'))
            
            # from np.array to list dtype U4/U5
            W_var = list(np.array(W_var, dtype='U20'))
            X_s_var = list(np.array(X_s_var, dtype='U20'))  
            X_v_var = list(np.array(X_v_var, dtype='U20')) 
            T_var = list(np.array(T_var, dtype='U20'))
            A_var = list(np.array(A_var, dtype='U20'))
                            
    W = np.concatenate((W_dev, W_test), axis=0)  
    X_s = np.concatenate((X_s_dev, X_s_test), axis=0)
    X_v = np.concatenate((X_v_dev, X_v_test), axis=0)
    T = np.concatenate((T_dev, T_test), axis=0)
    Y = np.concatenate((Y_dev, Y_test), axis=0) 
    A = np.concatenate((A_dev, A_test), axis=0) 


    print('')
    print("Operation time (min): " , (time.process_time()-t)/60)
    print(f"\nData Points")
    print ("W shape: ", str(W.shape), type(W))
    print ("X_s shape: ", str(X_s.shape), type(X_s))
    print ("X_v shape: ", str(X_v.shape), type(X_v))
    print ("T shape: ", str(T.shape), type(T))
    print ("A shape: ", str(A.shape), type(A))
    
    # Features labels
    print(f"\nLabels")
    print (f"W_var type: {type(W_var)} shape: {len(W_var)}, sample: {W_var[:5]}")
    print (f"X_s_var shape: " , type(X_s_var), len(X_s_var), X_s_var[:5])
    print (f"X_v_var shape: ", type(X_v_var), len(X_v_var), X_v_var[:5])
    print (f"T_var shape: ", type(T_var), len(T_var), T_var[:5])
    print (f"A_var shape: ", type(A_var), len(A_var), A_var[:5])
    
    # Target
    print(f"\nTarget")
    print ("Y shape: ", type(Y), len(Y))

    # Prepare Datasets
    df_W = DataFrame(data=W, columns=W_var)
    df_X_s = DataFrame(data=X_s, columns=X_s_var)
    df_X_v = DataFrame(data=X_v, columns=X_v_var)
    df_T = DataFrame(data=T, columns=T_var)
    df_A = DataFrame(data=A, columns=A_var)
    df_Y = DataFrame(data=Y, columns=['RUL'])

    return df_W, df_X_s, df_X_v, df_T, df_A, df_Y

# %% [markdown]
# Call the read function and store in DB

# %%
### Set-up - Define file location
db_set2 = 'TurboFanDegradation_Set2'
database = server[db_set2]

source_path = '/Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/'
data_files = [
    'N-CMAPSS_DS01-005.h5', 'N-CMAPSS_DS02-006.h5', 'N-CMAPSS_DS03-012.h5', 'N-CMAPSS_DS04.h5', 'N-CMAPSS_DS05.h5',
    'N-CMAPSS_DS06.h5', 'N-CMAPSS_DS07.h5', 'N-CMAPSS_DS08a-009.h5', 'N-CMAPSS_DS08c-008.h5'
    ]
collection_names = [
    'DS01', 'DS02', 'DS03', 'DS04', 'DS05',
    'DS06', 'DS07', 'DS08a', 'DS08c'
    ]

for i in range(len(data_files)):
    file_path = ''.join([source_path, data_files[i]])

    print('Read source file ......', file_path)

    df_W, df_X_s, df_X_v, df_T, df_A, df_Y = read_h5_file(file_path)

    print("\nDataframes from datapoints and labels")
    print('df_w', type(df_W), df_W.shape)
    print('df_X_s', type(df_X_s), df_X_s.shape)
    print('df_X_v', type(df_X_v), df_X_v.shape)
    print('df_T', type(df_T), df_T.shape)
    print('df_A', type(df_A), df_A.shape)
    print('df_A', type(df_Y), df_Y.shape)

    print('Create mongodb collections ....')

    colection = database[''.join([collection_names[i], '_W'])]
    print('Create collection:', colection)
    new_data = colection.insert_many(df_W.to_dict('records'))

    colection = database[''.join([collection_names[i], '_X_s'])]
    print('Create collection:', colection)
    new_data = colection.insert_many(df_X_s.to_dict('records'))

    colection = database[''.join([collection_names[i], '_X_v'])]
    print('Create collection:', colection)
    new_data = colection.insert_many(df_X_v.to_dict('records'))

    colection = database[''.join([collection_names[i], '_T'])]
    print('Create collection:', colection)
    new_data = colection.insert_many(df_T.to_dict('records'))

    colection = database[''.join([collection_names[i], '_A'])]
    print('Create collection:', colection)
    new_data = colection.insert_many(df_A.to_dict('records'))

    colection = database[''.join([collection_names[i], '_Y'])]
    print('Create collection:', colection)
    new_data = colection.insert_many(df_Y.to_dict('records'))
# Out:
# Read source file ...... /Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/N-CMAPSS_DS01-005.h5
#
# Operation time (min):  0.07915991666666665
#
# Data Points
# W shape:  (7641868, 4) <class 'numpy.ndarray'>
# X_s shape:  (7641868, 14) <class 'numpy.ndarray'>
# X_v shape:  (7641868, 14) <class 'numpy.ndarray'>
# T shape:  (7641868, 10) <class 'numpy.ndarray'>
# A shape:  (7641868, 4) <class 'numpy.ndarray'>
#
# Labels
# W_var type: <class 'list'> shape: 4, sample: ['alt', 'Mach', 'TRA', 'T2']
# X_s_var shape:  <class 'list'> 14 ['T24', 'T30', 'T48', 'T50', 'P15']
# X_v_var shape:  <class 'list'> 14 ['T40', 'P30', 'P45', 'W21', 'W22']
# T_var shape:  <class 'list'> 10 ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod']
# A_var shape:  <class 'list'> 4 ['unit', 'cycle', 'Fc', 'hs']
#
# Target
# Y shape:  <class 'numpy.ndarray'> 7641868
#
# Dataframes from datapoints and labels
# df_w <class 'pandas.core.frame.DataFrame'> (7641868, 4)
# df_X_s <class 'pandas.core.frame.DataFrame'> (7641868, 14)
# df_X_v <class 'pandas.core.frame.DataFrame'> (7641868, 14)
# df_T <class 'pandas.core.frame.DataFrame'> (7641868, 10)
# df_A <class 'pandas.core.frame.DataFrame'> (7641868, 4)
# df_A <class 'pandas.core.frame.DataFrame'> (7641868, 1)
# Create mongodb collections ....
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS01_W')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS01_X_s')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS01_X_v')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS01_T')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS01_A')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS01_Y')
# Read source file ...... /Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/N-CMAPSS_DS02-006.h5
#
# Operation time (min):  0.062729383333334
#
# Data Points
# W shape:  (6517190, 4) <class 'numpy.ndarray'>
# X_s shape:  (6517190, 14) <class 'numpy.ndarray'>
# X_v shape:  (6517190, 14) <class 'numpy.ndarray'>
# T shape:  (6517190, 10) <class 'numpy.ndarray'>
# A shape:  (6517190, 4) <class 'numpy.ndarray'>
#
# Labels
# W_var type: <class 'list'> shape: 4, sample: ['alt', 'Mach', 'TRA', 'T2']
# X_s_var shape:  <class 'list'> 14 ['T24', 'T30', 'T48', 'T50', 'P15']
# X_v_var shape:  <class 'list'> 14 ['T40', 'P30', 'P45', 'W21', 'W22']
# T_var shape:  <class 'list'> 10 ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod']
# A_var shape:  <class 'list'> 4 ['unit', 'cycle', 'Fc', 'hs']
#
# Target
# Y shape:  <class 'numpy.ndarray'> 6517190
#
# Dataframes from datapoints and labels
# df_w <class 'pandas.core.frame.DataFrame'> (6517190, 4)
# df_X_s <class 'pandas.core.frame.DataFrame'> (6517190, 14)
# df_X_v <class 'pandas.core.frame.DataFrame'> (6517190, 14)
# df_T <class 'pandas.core.frame.DataFrame'> (6517190, 10)
# df_A <class 'pandas.core.frame.DataFrame'> (6517190, 4)
# df_A <class 'pandas.core.frame.DataFrame'> (6517190, 1)
# Create mongodb collections ....
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS02_W')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS02_X_s')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS02_X_v')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS02_T')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS02_A')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS02_Y')
# Read source file ...... /Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/N-CMAPSS_DS03-012.h5
#
# Operation time (min):  0.09580958333333456
#
# Data Points
# W shape:  (9822837, 4) <class 'numpy.ndarray'>
# X_s shape:  (9822837, 14) <class 'numpy.ndarray'>
# X_v shape:  (9822837, 14) <class 'numpy.ndarray'>
# T shape:  (9822837, 10) <class 'numpy.ndarray'>
# A shape:  (9822837, 4) <class 'numpy.ndarray'>
#
# Labels
# W_var type: <class 'list'> shape: 4, sample: ['alt', 'Mach', 'TRA', 'T2']
# X_s_var shape:  <class 'list'> 14 ['T24', 'T30', 'T48', 'T50', 'P15']
# X_v_var shape:  <class 'list'> 14 ['T40', 'P30', 'P45', 'W21', 'W22']
# T_var shape:  <class 'list'> 10 ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod']
# A_var shape:  <class 'list'> 4 ['unit', 'cycle', 'Fc', 'hs']
#
# Target
# Y shape:  <class 'numpy.ndarray'> 9822837
#
# Dataframes from datapoints and labels
# df_w <class 'pandas.core.frame.DataFrame'> (9822837, 4)
# df_X_s <class 'pandas.core.frame.DataFrame'> (9822837, 14)
# df_X_v <class 'pandas.core.frame.DataFrame'> (9822837, 14)
# df_T <class 'pandas.core.frame.DataFrame'> (9822837, 10)
# df_A <class 'pandas.core.frame.DataFrame'> (9822837, 4)
# df_A <class 'pandas.core.frame.DataFrame'> (9822837, 1)
# Create mongodb collections ....
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS03_W')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS03_X_s')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS03_X_v')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS03_T')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS03_A')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS03_Y')
# Read source file ...... /Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/N-CMAPSS_DS04.h5
#
# Operation time (min):  0.08738121666666908
#
# Data Points
# W shape:  (9980013, 4) <class 'numpy.ndarray'>
# X_s shape:  (9980013, 14) <class 'numpy.ndarray'>
# X_v shape:  (9980013, 14) <class 'numpy.ndarray'>
# T shape:  (9980013, 10) <class 'numpy.ndarray'>
# A shape:  (9980013, 4) <class 'numpy.ndarray'>
#
# Labels
# W_var type: <class 'list'> shape: 4, sample: ['alt', 'Mach', 'TRA', 'T2']
# X_s_var shape:  <class 'list'> 14 ['T24', 'T30', 'T48', 'T50', 'P15']
# X_v_var shape:  <class 'list'> 14 ['T40', 'P30', 'P45', 'W21', 'W22']
# T_var shape:  <class 'list'> 10 ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod']
# A_var shape:  <class 'list'> 4 ['unit', 'cycle', 'Fc', 'hs']
#
# Target
# Y shape:  <class 'numpy.ndarray'> 9980013
#
# Dataframes from datapoints and labels
# df_w <class 'pandas.core.frame.DataFrame'> (9980013, 4)
# df_X_s <class 'pandas.core.frame.DataFrame'> (9980013, 14)
# df_X_v <class 'pandas.core.frame.DataFrame'> (9980013, 14)
# df_T <class 'pandas.core.frame.DataFrame'> (9980013, 10)
# df_A <class 'pandas.core.frame.DataFrame'> (9980013, 4)
# df_A <class 'pandas.core.frame.DataFrame'> (9980013, 1)
# Create mongodb collections ....
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS04_W')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS04_X_s')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS04_X_v')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS04_T')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS04_A')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS04_Y')
# Read source file ...... /Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/N-CMAPSS_DS05.h5
#
# Operation time (min):  0.06104221666666566
#
# Data Points
# W shape:  (6912652, 4) <class 'numpy.ndarray'>
# X_s shape:  (6912652, 14) <class 'numpy.ndarray'>
# X_v shape:  (6912652, 14) <class 'numpy.ndarray'>
# T shape:  (6912652, 10) <class 'numpy.ndarray'>
# A shape:  (6912652, 4) <class 'numpy.ndarray'>
#
# Labels
# W_var type: <class 'list'> shape: 4, sample: ['alt', 'Mach', 'TRA', 'T2']
# X_s_var shape:  <class 'list'> 14 ['T24', 'T30', 'T48', 'T50', 'P15']
# X_v_var shape:  <class 'list'> 14 ['T40', 'P30', 'P45', 'W21', 'W22']
# T_var shape:  <class 'list'> 10 ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod']
# A_var shape:  <class 'list'> 4 ['unit', 'cycle', 'Fc', 'hs']
#
# Target
# Y shape:  <class 'numpy.ndarray'> 6912652
#
# Dataframes from datapoints and labels
# df_w <class 'pandas.core.frame.DataFrame'> (6912652, 4)
# df_X_s <class 'pandas.core.frame.DataFrame'> (6912652, 14)
# df_X_v <class 'pandas.core.frame.DataFrame'> (6912652, 14)
# df_T <class 'pandas.core.frame.DataFrame'> (6912652, 10)
# df_A <class 'pandas.core.frame.DataFrame'> (6912652, 4)
# df_A <class 'pandas.core.frame.DataFrame'> (6912652, 1)
# Create mongodb collections ....
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS05_W')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS05_X_s')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS05_X_v')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS05_T')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS05_A')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS05_Y')
# Read source file ...... /Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/N-CMAPSS_DS06.h5
#
# Operation time (min):  0.05415631666666438
#
# Data Points
# W shape:  (6779656, 4) <class 'numpy.ndarray'>
# X_s shape:  (6779656, 14) <class 'numpy.ndarray'>
# X_v shape:  (6779656, 14) <class 'numpy.ndarray'>
# T shape:  (6779656, 10) <class 'numpy.ndarray'>
# A shape:  (6779656, 4) <class 'numpy.ndarray'>
#
# Labels
# W_var type: <class 'list'> shape: 4, sample: ['alt', 'Mach', 'TRA', 'T2']
# X_s_var shape:  <class 'list'> 14 ['T24', 'T30', 'T48', 'T50', 'P15']
# X_v_var shape:  <class 'list'> 14 ['T40', 'P30', 'P45', 'W21', 'W22']
# T_var shape:  <class 'list'> 10 ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod']
# A_var shape:  <class 'list'> 4 ['unit', 'cycle', 'Fc', 'hs']
#
# Target
# Y shape:  <class 'numpy.ndarray'> 6779656
#
# Dataframes from datapoints and labels
# df_w <class 'pandas.core.frame.DataFrame'> (6779656, 4)
# df_X_s <class 'pandas.core.frame.DataFrame'> (6779656, 14)
# df_X_v <class 'pandas.core.frame.DataFrame'> (6779656, 14)
# df_T <class 'pandas.core.frame.DataFrame'> (6779656, 10)
# df_A <class 'pandas.core.frame.DataFrame'> (6779656, 4)
# df_A <class 'pandas.core.frame.DataFrame'> (6779656, 1)
# Create mongodb collections ....
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS06_W')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS06_X_s')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS06_X_v')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS06_T')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS06_A')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS06_Y')
# Read source file ...... /Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/N-CMAPSS_DS07.h5
#
# Operation time (min):  0.0542100666666632
#
# Data Points
# W shape:  (7219962, 4) <class 'numpy.ndarray'>
# X_s shape:  (7219962, 14) <class 'numpy.ndarray'>
# X_v shape:  (7219962, 14) <class 'numpy.ndarray'>
# T shape:  (7219962, 10) <class 'numpy.ndarray'>
# A shape:  (7219962, 4) <class 'numpy.ndarray'>
#
# Labels
# W_var type: <class 'list'> shape: 4, sample: ['alt', 'Mach', 'TRA', 'T2']
# X_s_var shape:  <class 'list'> 14 ['T24', 'T30', 'T48', 'T50', 'P15']
# X_v_var shape:  <class 'list'> 14 ['T40', 'P30', 'P45', 'W21', 'W22']
# T_var shape:  <class 'list'> 10 ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod']
# A_var shape:  <class 'list'> 4 ['unit', 'cycle', 'Fc', 'hs']
#
# Target
# Y shape:  <class 'numpy.ndarray'> 7219962
#
# Dataframes from datapoints and labels
# df_w <class 'pandas.core.frame.DataFrame'> (7219962, 4)
# df_X_s <class 'pandas.core.frame.DataFrame'> (7219962, 14)
# df_X_v <class 'pandas.core.frame.DataFrame'> (7219962, 14)
# df_T <class 'pandas.core.frame.DataFrame'> (7219962, 10)
# df_A <class 'pandas.core.frame.DataFrame'> (7219962, 4)
# df_A <class 'pandas.core.frame.DataFrame'> (7219962, 1)
# Create mongodb collections ....
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS07_W')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS07_X_s')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS07_X_v')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS07_T')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS07_A')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS07_Y')
# Read source file ...... /Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/N-CMAPSS_DS08a-009.h5
#
# Operation time (min):  0.06720953333333454
#
# Data Points
# W shape:  (8608386, 4) <class 'numpy.ndarray'>
# X_s shape:  (8608386, 14) <class 'numpy.ndarray'>
# X_v shape:  (8608386, 14) <class 'numpy.ndarray'>
# T shape:  (8608386, 10) <class 'numpy.ndarray'>
# A shape:  (8608386, 4) <class 'numpy.ndarray'>
#
# Labels
# W_var type: <class 'list'> shape: 4, sample: ['alt', 'Mach', 'TRA', 'T2']
# X_s_var shape:  <class 'list'> 14 ['T24', 'T30', 'T48', 'T50', 'P15']
# X_v_var shape:  <class 'list'> 14 ['T40', 'P30', 'P45', 'W21', 'W22']
# T_var shape:  <class 'list'> 10 ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod']
# A_var shape:  <class 'list'> 4 ['unit', 'cycle', 'Fc', 'hs']
#
# Target
# Y shape:  <class 'numpy.ndarray'> 8608386
#
# Dataframes from datapoints and labels
# df_w <class 'pandas.core.frame.DataFrame'> (8608386, 4)
# df_X_s <class 'pandas.core.frame.DataFrame'> (8608386, 14)
# df_X_v <class 'pandas.core.frame.DataFrame'> (8608386, 14)
# df_T <class 'pandas.core.frame.DataFrame'> (8608386, 10)
# df_A <class 'pandas.core.frame.DataFrame'> (8608386, 4)
# df_A <class 'pandas.core.frame.DataFrame'> (8608386, 1)
# Create mongodb collections ....
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08a_W')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08a_X_s')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08a_X_v')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08a_T')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08a_A')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08a_Y')
# Read source file ...... /Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/N-CMAPSS_DS08c-008.h5
#
# Operation time (min):  0.04754738333332777
#
# Data Points
# W shape:  (6417737, 4) <class 'numpy.ndarray'>
# X_s shape:  (6417737, 14) <class 'numpy.ndarray'>
# X_v shape:  (6417737, 14) <class 'numpy.ndarray'>
# T shape:  (6417737, 10) <class 'numpy.ndarray'>
# A shape:  (6417737, 4) <class 'numpy.ndarray'>
#
# Labels
# W_var type: <class 'list'> shape: 4, sample: ['alt', 'Mach', 'TRA', 'T2']
# X_s_var shape:  <class 'list'> 14 ['T24', 'T30', 'T48', 'T50', 'P15']
# X_v_var shape:  <class 'list'> 14 ['T40', 'P30', 'P45', 'W21', 'W22']
# T_var shape:  <class 'list'> 10 ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod']
# A_var shape:  <class 'list'> 4 ['unit', 'cycle', 'Fc', 'hs']
#
# Target
# Y shape:  <class 'numpy.ndarray'> 6417737
#
# Dataframes from datapoints and labels
# df_w <class 'pandas.core.frame.DataFrame'> (6417737, 4)
# df_X_s <class 'pandas.core.frame.DataFrame'> (6417737, 14)
# df_X_v <class 'pandas.core.frame.DataFrame'> (6417737, 14)
# df_T <class 'pandas.core.frame.DataFrame'> (6417737, 10)
# df_A <class 'pandas.core.frame.DataFrame'> (6417737, 4)
# df_A <class 'pandas.core.frame.DataFrame'> (6417737, 1)
# Create mongodb collections ....
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08c_W')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08c_X_s')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08c_X_v')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08c_T')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08c_A')
# Create collection: Collection(Database(MongoClient(host=['192.168.1.20:27017'], document_class=dict, tz_aware=False, connect=True), 'TurboFanDegradation_Set2'), 'DS08c_Y')
# Read source file ...... /Volumes/share/Datasets/17_TurbofanEngineDegradationSimulationDataSet2/data_set/N-CMAPSS_DS08d-010.h5
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 20
#      16 file_path = ''.join([source_path, data_files[i]])
#      18 print('Read source file ......', file_path)
# ---> 20 df_W, df_X_s, df_X_v, df_T, df_A, df_Y = read_h5_file(file_path)
#      22 print("\nDataframes from datapoints and labels")
#      23 print('df_w', type(df_W), df_W.shape)
#
# Cell In[17], line 8, in read_h5_file(filename)
#       5 t = time.process_time()
#       7 # Load data
# ----> 8 with h5py.File(filename, 'r') as hdf:
#       9         # Development set
#      10         W_dev = np.array(hdf.get('W_dev'))             # W
#      11         X_s_dev = np.array(hdf.get('X_s_dev'))         # X_s
#
# File /opt/miniconda3/envs/py39_12/lib/python3.9/site-packages/h5py/_hl/files.py:533, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, **kwds)
#     525     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     526                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     527                      alignment_threshold=alignment_threshold,
#     528                      alignment_interval=alignment_interval,
#     529                      **kwds)
#     530     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     531                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     532                      fs_page_size=fs_page_size)
# --> 533     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     535 if isinstance(libver, tuple):
#     536     self._libver = libver
#
# File /opt/miniconda3/envs/py39_12/lib/python3.9/site-packages/h5py/_hl/files.py:226, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     224     if swmr and swmr_support:
#     225         flags |= h5f.ACC_SWMR_READ
# --> 226     fid = h5f.open(name, flags, fapl=fapl)
#     227 elif mode == 'r+':
#     228     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# OSError: Unable to open file (truncated file: eof = 2885034848, sblock->base_addr = 0, stored_eof = 2885034880)
